# %% [markdown]
# # Notebook to explore, clean, and merge our raw data

# %%
# pandas library for data manipulation
import pandas as pd 

# numpy library for numerical calculations
import numpy as np

# matplotlib or seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the raw data

# %% [markdown]
# ### Imports data

# %%
imports_data = pd.read_csv('../data/raw_data/imports_main.csv')
imports_data.head()
# Out:
#          Importer       TEU  Month  Unlading_Port Origin_Country  HS_Codes
# 0  Importer_00001  0.849421      1           4601         POLAND    990500
# 1  Importer_00002  1.000000      1           1401          ITALY    330590
# 2  Importer_00003  2.000000      1           5301        BELGIUM    730890
# 3  Importer_00004  0.035356      1           5301        GERMANY    580620
# 4  Importer_00005  4.000000      1           4601        DENMARK    392030

# %%
imports_data.drop(columns=['Importer', 'Unlading_Port'], inplace=True)
imports_data.head()
# Out:
#         TEU  Month Origin_Country  HS_Codes
# 0  0.849421      1         POLAND    990500
# 1  1.000000      1          ITALY    330590
# 2  2.000000      1        BELGIUM    730890
# 3  0.035356      1        GERMANY    580620
# 4  4.000000      1        DENMARK    392030

# %% [markdown]
# ### Country Codes

# %%
country_codes = pd.read_csv('../data/raw_data/country_codes.csv')
country_codes.head()
# Out:
#              name alpha-2 alpha-3  country-code     iso_3166-2   region  \
# 0     Afghanistan      AF     AFG             4  ISO 3166-2:AF     Asia
# 1   Åland Islands      AX     ALA           248  ISO 3166-2:AX   Europe
# 2         Albania      AL     ALB             8  ISO 3166-2:AL   Europe
# 3         Algeria      DZ     DZA            12  ISO 3166-2:DZ   Africa
# 4  American Samoa      AS     ASM            16  ISO 3166-2:AS  Oceania
#
#         sub-region intermediate-region  region-code  sub-region-code  \
# 0    Southern Asia                 NaN        142.0             34.0
# 1  Northern Europe                 NaN        150.0            154.0
# 2  Southern Europe                 NaN        150.0             39.0
# 3  Northern Africa                 NaN          2.0             15.0
# 4        Polynesia                 NaN          9.0             61.0
#
#    intermediate-region-code
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN

# %%
country_codes = country_codes[['name','alpha-3']]
country_codes.head()
# Out:
#              name alpha-3
# 0     Afghanistan     AFG
# 1   Åland Islands     ALA
# 2         Albania     ALB
# 3         Algeria     DZA
# 4  American Samoa     ASM

# %% [markdown]
# ### Sea Distance

# %%
sea_distance = pd.read_excel('../data/raw_data/CERDI-seadistance.xlsx')
sea_distance.head()
# Out:
#   iso1 iso2  seadistance  capitalport1  capitalport2  roaddistance  short
# 0  ABW  AFG    16498.800           NaN      1471.300           NaN      0
# 1  ABW  AGO     9437.060           NaN      1184.170           NaN      0
# 2  ABW  AIA      956.853           NaN           NaN           NaN      0
# 3  ABW  ALB     8790.060           NaN       247.952           NaN      0
# 4  ABW  AND     7685.420           NaN       453.335           NaN      0

# %%
sea_distance = sea_distance[['iso1','iso2','seadistance']]
sea_distance.head()
# Out:
#   iso1 iso2  seadistance
# 0  ABW  AFG    16498.800
# 1  ABW  AGO     9437.060
# 2  ABW  AIA      956.853
# 3  ABW  ALB     8790.060
# 4  ABW  AND     7685.420

# %% [markdown]
# ### Tariff Data

# %%
tariff_data = pd.read_excel('../data/raw_data/tariff_database_202405.xlsx')
tariff_data.head()
# Out:
#       hts8                                  brief_description quantity_1_code  \
# 0  1012100                      Live purebred breeding horses              NO
# 1  1012900    Live horses other than purebred breeding horses              NO
# 2  1013000                                         Live asses              NO
# 3  1019030  Mules and hinnies imported for immediate slaug...              NO
# 4  1019040  Mules and hinnies not imported for immediate s...              NO
#
#   quantity_2_code wto_binding_code mfn_text_rate mfn_rate_type_code  mfn_ave  \
# 0             NaN                B          Free                  0      NaN
# 1             NaN                B          Free                  0      NaN
# 2             NaN                B          6.8%                  7      NaN
# 3             NaN                B          Free                  0      NaN
# 4             NaN                B          4.5%                  7      NaN
#
#    mfn_ad_val_rate  mfn_specific_rate  ...  japan_indicator  \
# 0            0.000                0.0  ...              NaN
# 1            0.000                0.0  ...              NaN
# 2            0.068                0.0  ...              NaN
# 3            0.000                0.0  ...              NaN
# 4            0.045                0.0  ...              NaN
#
#   japan_rate_type_code  japan_ad_val_rate japan_specific_rate  \
# 0                  NaN                NaN                 NaN
# 1                  NaN                NaN                 NaN
# 2                  NaN                NaN                 NaN
# 3                  NaN                NaN                 NaN
# 4                  NaN                NaN                 NaN
#
#   japan_other_rate usmca_indicator usmca_rate_type_code usmca_ad_val_rate  \
# 0              NaN             NaN                  NaN               NaN
# 1              NaN             NaN                  NaN               NaN
# 2              NaN               S                  0.0               0.0
# 3              NaN             NaN                  NaN               NaN
# 4              NaN               S                  0.0               0.0
#
#   usmca_specific_rate usmca_other_rate
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 0.0              0.0
# 3                 NaN              NaN
# 4                 0.0              0.0
#
# [5 rows x 122 columns]

# %% [markdown]
# ### WGI_data

# %%
wgi_data = pd.read_excel('../data/raw_data/wgidataset.xlsx')
wgi_data.head()
# Out:
#    codeindyr code     countryname  year indicator  estimate    stddev nsource  \
# 0  AFGcc1996  AFG     Afghanistan  1996        cc -1.291705  0.340507       2
# 1  ALBcc1996  ALB         Albania  1996        cc -0.893903  0.315914       3
# 2  DZAcc1996  DZA         Algeria  1996        cc -0.566741  0.262077       4
# 3  ASMcc1996  ASM  American Samoa  1996        cc        ..        ..      ..
# 4  ADOcc1996  ADO         Andorra  1996        cc  1.318143  0.480889       1
#
#      pctrank pctranklower pctrankupper
# 0   4.301075            0    27.419355
# 1  19.354839     2.688172    43.010754
# 2  33.333332    16.666666    52.688171
# 3         ..           ..           ..
# 4  87.096771    72.043015    96.774193

# %%
wgi_data.tail()
# Out:
#        codeindyr code            countryname  year indicator  estimate  \
# 32095  VIRva2023  VIR  Virgin Islands (U.S.)  2023        va        ..
# 32096  WBGva2023  WBG     West Bank and Gaza  2023        va -1.118067
# 32097  YEMva2023  YEM            Yemen, Rep.  2023        va -1.550217
# 32098  ZMBva2023  ZMB                 Zambia  2023        va -0.047946
# 32099  ZWEva2023  ZWE               Zimbabwe  2023        va -1.092633
#
#          stddev nsource    pctrank pctranklower pctrankupper
# 32095        ..      ..         ..           ..           ..
# 32096  0.149837       6  18.137255    11.764706    24.509804
# 32097  0.131432       8   6.372549      2.45098    11.764706
# 32098  0.118482      12  45.098038    39.215687    52.450981
# 32099  0.118235      13  19.117647    12.745098    24.509804

# %%
wgi_data = wgi_data[wgi_data['year'] == 2023]
wgi_data.head()
# Out:
#        codeindyr code     countryname  year indicator  estimate    stddev  \
# 30816  AFGcc2023  AFG     Afghanistan  2023        cc -1.154932  0.173359
# 30817  ALBcc2023  ALB         Albania  2023        cc -0.332219  0.158822
# 30818  DZAcc2023  DZA         Algeria  2023        cc -0.589308  0.172194
# 30819  ASMcc2023  ASM  American Samoa  2023        cc  1.251356  0.461191
# 30820  ADOcc2023  ADO         Andorra  2023        cc  1.251356  0.461191
#
#       nsource    pctrank pctranklower pctrankupper
# 30816       8  13.679245     6.132075    20.754717
# 30817       9  43.396225    29.716982    51.886791
# 30818       8  30.188679    20.754717     45.28302
# 30819       1  87.735847     65.56604    96.698112
# 30820       1  87.735847     65.56604    96.698112

# %%
wgi_data = wgi_data[['code','countryname','estimate']]
wgi_data.head()
# Out:
#       code     countryname  estimate
# 30816  AFG     Afghanistan -1.154932
# 30817  ALB         Albania -0.332219
# 30818  DZA         Algeria -0.589308
# 30819  ASM  American Samoa  1.251356
# 30820  ADO         Andorra  1.251356

# %% [markdown]
# # Data Merging
#
# note: no need to rerun, use merged_df and merged_df2 from data/preprocessed_data

# %% [markdown]
# ## Left Join country_codes

# %%
imports_data.head()
# Out:
#         TEU  Month Origin_Country  HS_Codes
# 0  0.849421      1         poland    990500
# 1  1.000000      1          italy    330590
# 2  2.000000      1        belgium    730890
# 3  0.035356      1        germany    580620
# 4  4.000000      1        denmark    392030

# %%
country_codes.head()
# Out:
#              name alpha-3
# 0     afghanistan     AFG
# 1   åland islands     ALA
# 2         albania     ALB
# 3         algeria     DZA
# 4  american samoa     ASM

# %%
imports_data.dtypes
# Out:
# TEU               float64
# Month               int64
# Origin_Country     object
# HS_Codes            int64
# dtype: object

# %%
imports_data[imports_data['Origin_Country'].isnull()]
# Out:
#          TEU  Month Origin_Country  HS_Codes
# 656331   1.0      7            NaN    980400
# 2444879  1.0      3            NaN    430219
# 3289576  2.0      9            NaN    999900

# %%
imports_data.dropna(subset=['Origin_Country'], inplace=True)
imports_data[imports_data['Origin_Country'].isnull()]
# Out:
# Empty DataFrame
# Columns: [TEU, Month, Origin_Country, HS_Codes]
# Index: []

# %%
imports_data['Origin_Country'] = imports_data['Origin_Country'].apply(lambda x: x.lower())
imports_data.tail()
# Out:
#               TEU  Month Origin_Country  HS_Codes
# 4158449  1.000000      3          china    960390
# 4158450  0.729055      3         turkey    610433
# 4158451  0.041950      3        germany    510910
# 4158452  2.000000      3         turkey    680291
# 4158453  2.000000      3          china    950300

# %%
country_codes['name'] = country_codes['name'].apply(lambda x: x.lower())
country_codes.head()
# Out:
#              name alpha-3
# 0     afghanistan     AFG
# 1   åland islands     ALA
# 2         albania     ALB
# 3         algeria     DZA
# 4  american samoa     ASM

# %%
merged_df = pd.merge(imports_data, country_codes, left_on = 'Origin_Country', right_on = 'name', how = 'left')
merged_df.head()
# Out:
#         TEU  Month Origin_Country  HS_Codes     name alpha-3
# 0  0.849421      1         poland    990500   poland     POL
# 1  1.000000      1          italy    330590    italy     ITA
# 2  2.000000      1        belgium    730890  belgium     BEL
# 3  0.035356      1        germany    580620  germany     DEU
# 4  4.000000      1        denmark    392030  denmark     DNK

# %%
merged_df['name'].isna().sum()
# Out:
# np.int64(1156290)

# %%
mismatched = list(merged_df[merged_df['name'].isna()]['Origin_Country'].unique())
print(mismatched)
# Out:
# ['hong kong s.a.r.', 'macau s.a.r.', 'netherlands', 'korea south', 'united states', 'united kingdom', 'czech republic', 'turkey', 'vietnam', 'taiwan', 'iran', 'russia', "cote d'ivoire (ivory coast)", 'swaziland', 'saint helena', 'macedonia', 'laos', 'moldova', 'aland islands', 'virgin islands (us)', 'croatia (hrvatska)', 'reunion', 'bolivia', 'fiji islands', 'venezuela', 'man (isle of)', 'tanzania', 'east timor', 'brunei', 'syria', 'saint-barthelemy', 'vatican city state (holy see)', 'cape verde', 'korea north', 'congo the democratic republic of the', 'kosovo', 'bonaire, saint eustatius and saba', 'palestinian territory occupied']

# %%
len(mismatched)
# Out:
# 38

# %%
for name in mismatched:
    print(name)
    print(country_codes[country_codes['name'].str.startswith(name[:3])])
    print('-'*70)
# Out:
# hong kong s.a.r.
#           name alpha-3
# 99    honduras     HND
# 100  hong kong     HKG
# ----------------------------------------------------------------------
# macau s.a.r.
#       name alpha-3
# 131  macao     MAC
# ----------------------------------------------------------------------
# netherlands
#                             name alpha-3
# 156  netherlands, kingdom of the     NLD
# ----------------------------------------------------------------------
# korea south
#                                        name alpha-3
# 118  korea, democratic people's republic of     PRK
# 119                      korea, republic of     KOR
# ----------------------------------------------------------------------
# united states
#                                                   name alpha-3
# 233                               united arab emirates     ARE
# 234  united kingdom of great britain and northern i...     GBR
# 235                           united states of america     USA
# 236               united states minor outlying islands     UMI
# ----------------------------------------------------------------------
# united kingdom
#                                                   name alpha-3
# 233                               united arab emirates     ARE
# 234  united kingdom of great britain and northern i...     GBR
# 235                           united states of america     USA
# 236               united states minor outlying islands     UMI
# ----------------------------------------------------------------------
# czech republic
#        name alpha-3
# 59  czechia     CZE
# ----------------------------------------------------------------------
# turkey
#                          name alpha-3
# 228              turkmenistan     TKM
# 229  turks and caicos islands     TCA
# ----------------------------------------------------------------------
# vietnam
#          name alpha-3
# 241  viet nam     VNM
# ----------------------------------------------------------------------
# taiwan
#                           name alpha-3
# 217  taiwan, province of china     TWN
# ----------------------------------------------------------------------
# iran
#                           name alpha-3
# 105  iran, islamic republic of     IRN
# 106                       iraq     IRQ
# ----------------------------------------------------------------------
# russia
#                    name alpha-3
# 183  russian federation     RUS
# ----------------------------------------------------------------------
# cote d'ivoire (ivory coast)
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# ----------------------------------------------------------------------
# swaziland
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# ----------------------------------------------------------------------
# saint helena
#                                              name alpha-3
# 185                              saint barthélemy     BLM
# 186  saint helena, ascension and tristan da cunha     SHN
# 187                         saint kitts and nevis     KNA
# 188                                   saint lucia     LCA
# 189                    saint martin (french part)     MAF
# 190                     saint pierre and miquelon     SPM
# 191              saint vincent and the grenadines     VCT
# ----------------------------------------------------------------------
# macedonia
#       name alpha-3
# 131  macao     MAC
# ----------------------------------------------------------------------
# laos
#                                  name alpha-3
# 122  lao people's democratic republic     LAO
# ----------------------------------------------------------------------
# moldova
#                      name alpha-3
# 145  moldova, republic of     MDA
# ----------------------------------------------------------------------
# aland islands
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# ----------------------------------------------------------------------
# virgin islands (us)
#                          name alpha-3
# 242  virgin islands (british)     VGB
# 243     virgin islands (u.s.)     VIR
# ----------------------------------------------------------------------
# croatia (hrvatska)
#        name alpha-3
# 55  croatia     HRV
# ----------------------------------------------------------------------
# reunion
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# ----------------------------------------------------------------------
# bolivia
#                                name alpha-3
# 26  bolivia, plurinational state of     BOL
# ----------------------------------------------------------------------
# fiji islands
#     name alpha-3
# 74  fiji     FJI
# ----------------------------------------------------------------------
# venezuela
#                                   name alpha-3
# 240  venezuela, bolivarian republic of     VEN
# ----------------------------------------------------------------------
# man (isle of)
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# ----------------------------------------------------------------------
# tanzania
#                              name alpha-3
# 219  tanzania, united republic of     TZA
# ----------------------------------------------------------------------
# east timor
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# ----------------------------------------------------------------------
# brunei
#                  name alpha-3
# 33  brunei darussalam     BRN
# ----------------------------------------------------------------------
# syria
#                      name alpha-3
# 216  syrian arab republic     SYR
# ----------------------------------------------------------------------
# saint-barthelemy
#                                              name alpha-3
# 185                              saint barthélemy     BLM
# 186  saint helena, ascension and tristan da cunha     SHN
# 187                         saint kitts and nevis     KNA
# 188                                   saint lucia     LCA
# 189                    saint martin (french part)     MAF
# 190                     saint pierre and miquelon     SPM
# 191              saint vincent and the grenadines     VCT
# ----------------------------------------------------------------------
# vatican city state (holy see)
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# ----------------------------------------------------------------------
# cape verde
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# ----------------------------------------------------------------------
# korea north
#                                        name alpha-3
# 118  korea, democratic people's republic of     PRK
# 119                      korea, republic of     KOR
# ----------------------------------------------------------------------
# congo the democratic republic of the
#                                  name alpha-3
# 50                              congo     COG
# 51  congo, democratic republic of the     COD
# ----------------------------------------------------------------------
# kosovo
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# ----------------------------------------------------------------------
# bonaire, saint eustatius and saba
#                                 name alpha-3
# 27  bonaire, sint eustatius and saba     BES
# ----------------------------------------------------------------------
# palestinian territory occupied
#                     name alpha-3
# 169                palau     PLW
# 170  palestine, state of     PSE
# ----------------------------------------------------------------------

# %%
country_corrections = dict()
for name in mismatched:
    country_corrections.update({name: None})

country_corrections
# Out:
# {'hong kong s.a.r.': None,
#  'macau s.a.r.': None,
#  'netherlands': None,
#  'korea south': None,
#  'united states': None,
#  'united kingdom': None,
#  'czech republic': None,
#  'turkey': None,
#  'vietnam': None,
#  'taiwan': None,
#  'iran': None,
#  'russia': None,
#  "cote d'ivoire (ivory coast)": None,
#  'swaziland': None,
#  'saint helena': None,
#  'macedonia': None,
#  'laos': None,
#  'moldova': None,
#  'aland islands': None,
#  'virgin islands (us)': None,
#  'croatia (hrvatska)': None,
#  'reunion': None,
#  'bolivia': None,
#  'fiji islands': None,
#  'venezuela': None,
#  'man (isle of)': None,
#  'tanzania': None,
#  'east timor': None,
#  'brunei': None,
#  'syria': None,
#  'saint-barthelemy': None,
#  'vatican city state (holy see)': None,
#  'cape verde': None,
#  'korea north': None,
#  'congo the democratic republic of the': None,
#  'kosovo': None,
#  'bonaire, saint eustatius and saba': None,
#  'palestinian territory occupied': None}

# %%
for name in mismatched:
    print(f'You are correcting {name}:')
    print('Here are your options')
    options = country_codes[country_codes['name'].str.startswith(name[:3])]
    print(options)
    correct_index = input('Which index is correct?')
    if correct_index == 'na':
        print('no equivalent value')
        continue
    print(f'replacing ({name}) with ({options['name'].loc[int(correct_index)]})')
    country_corrections[name] = options['name'].loc[int(correct_index)]
    print('-'*70)
# Out:
# You are correcting hong kong s.a.r.:
# Here are your options
#           name alpha-3
# 99    honduras     HND
# 100  hong kong     HKG
# replacing (hong kong s.a.r.) with (hong kong)
# ----------------------------------------------------------------------
# You are correcting macau s.a.r.:
# Here are your options
#       name alpha-3
# 131  macao     MAC
# replacing (macau s.a.r.) with (macao)
# ----------------------------------------------------------------------
# You are correcting netherlands:
# Here are your options
#                             name alpha-3
# 156  netherlands, kingdom of the     NLD
# replacing (netherlands) with (netherlands, kingdom of the)
# ----------------------------------------------------------------------
# You are correcting korea south:
# Here are your options
#                                        name alpha-3
# 118  korea, democratic people's republic of     PRK
# 119                      korea, republic of     KOR
# replacing (korea south) with (korea, republic of)
# ----------------------------------------------------------------------
# You are correcting united states:
# Here are your options
#                                                   name alpha-3
# 233                               united arab emirates     ARE
# 234  united kingdom of great britain and northern i...     GBR
# 235                           united states of america     USA
# 236               united states minor outlying islands     UMI
# no equivalent value
# You are correcting united kingdom:
# Here are your options
#                                                   name alpha-3
# 233                               united arab emirates     ARE
# 234  united kingdom of great britain and northern i...     GBR
# 235                           united states of america     USA
# 236               united states minor outlying islands     UMI
# replacing (united kingdom) with (united kingdom of great britain and northern ireland)
# ----------------------------------------------------------------------
# You are correcting czech republic:
# Here are your options
#        name alpha-3
# 59  czechia     CZE
# replacing (czech republic) with (czechia)
# ----------------------------------------------------------------------
# You are correcting turkey:
# Here are your options
#                          name alpha-3
# 228              turkmenistan     TKM
# 229  turks and caicos islands     TCA
# no equivalent value
# You are correcting vietnam:
# Here are your options
#          name alpha-3
# 241  viet nam     VNM
# replacing (vietnam) with (viet nam)
# ----------------------------------------------------------------------
# You are correcting taiwan:
# Here are your options
#                           name alpha-3
# 217  taiwan, province of china     TWN
# replacing (taiwan) with (taiwan, province of china)
# ----------------------------------------------------------------------
# You are correcting iran:
# Here are your options
#                           name alpha-3
# 105  iran, islamic republic of     IRN
# 106                       iraq     IRQ
# replacing (iran) with (iran, islamic republic of)
# ----------------------------------------------------------------------
# You are correcting russia:
# Here are your options
#                    name alpha-3
# 183  russian federation     RUS
# replacing (russia) with (russian federation)
# ----------------------------------------------------------------------
# You are correcting cote d'ivoire (ivory coast):
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting swaziland:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting saint helena:
# Here are your options
#                                              name alpha-3
# 185                              saint barthélemy     BLM
# 186  saint helena, ascension and tristan da cunha     SHN
# 187                         saint kitts and nevis     KNA
# 188                                   saint lucia     LCA
# 189                    saint martin (french part)     MAF
# 190                     saint pierre and miquelon     SPM
# 191              saint vincent and the grenadines     VCT
# replacing (saint helena) with (saint helena, ascension and tristan da cunha)
# ----------------------------------------------------------------------
# You are correcting macedonia:
# Here are your options
#       name alpha-3
# 131  macao     MAC
# no equivalent value
# You are correcting laos:
# Here are your options
#                                  name alpha-3
# 122  lao people's democratic republic     LAO
# replacing (laos) with (lao people's democratic republic)
# ----------------------------------------------------------------------
# You are correcting moldova:
# Here are your options
#                      name alpha-3
# 145  moldova, republic of     MDA
# replacing (moldova) with (moldova, republic of)
# ----------------------------------------------------------------------
# You are correcting aland islands:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting virgin islands (us):
# Here are your options
#                          name alpha-3
# 242  virgin islands (british)     VGB
# 243     virgin islands (u.s.)     VIR
# no equivalent value
# You are correcting croatia (hrvatska):
# Here are your options
#        name alpha-3
# 55  croatia     HRV
# replacing (croatia (hrvatska)) with (croatia)
# ----------------------------------------------------------------------
# You are correcting reunion:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting bolivia:
# Here are your options
#                                name alpha-3
# 26  bolivia, plurinational state of     BOL
# replacing (bolivia) with (bolivia, plurinational state of)
# ----------------------------------------------------------------------
# You are correcting fiji islands:
# Here are your options
#     name alpha-3
# 74  fiji     FJI
# replacing (fiji islands) with (fiji)
# ----------------------------------------------------------------------
# You are correcting venezuela:
# Here are your options
#                                   name alpha-3
# 240  venezuela, bolivarian republic of     VEN
# replacing (venezuela) with (venezuela, bolivarian republic of)
# ----------------------------------------------------------------------
# You are correcting man (isle of):
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting tanzania:
# Here are your options
#                              name alpha-3
# 219  tanzania, united republic of     TZA
# no equivalent value
# You are correcting east timor:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting brunei:
# Here are your options
#                  name alpha-3
# 33  brunei darussalam     BRN
# replacing (brunei) with (brunei darussalam)
# ----------------------------------------------------------------------
# You are correcting syria:
# Here are your options
#                      name alpha-3
# 216  syrian arab republic     SYR
# replacing (syria) with (syrian arab republic)
# ----------------------------------------------------------------------
# You are correcting saint-barthelemy:
# Here are your options
#                                              name alpha-3
# 185                              saint barthélemy     BLM
# 186  saint helena, ascension and tristan da cunha     SHN
# 187                         saint kitts and nevis     KNA
# 188                                   saint lucia     LCA
# 189                    saint martin (french part)     MAF
# 190                     saint pierre and miquelon     SPM
# 191              saint vincent and the grenadines     VCT
# replacing (saint-barthelemy) with (saint barthélemy)
# ----------------------------------------------------------------------
# You are correcting vatican city state (holy see):
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting cape verde:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting korea north:
# Here are your options
#                                        name alpha-3
# 118  korea, democratic people's republic of     PRK
# 119                      korea, republic of     KOR
# no equivalent value
# You are correcting congo the democratic republic of the:
# Here are your options
#                                  name alpha-3
# 50                              congo     COG
# 51  congo, democratic republic of the     COD
# replacing (congo the democratic republic of the) with (congo, democratic republic of the)
# ----------------------------------------------------------------------
# You are correcting kosovo:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting bonaire, saint eustatius and saba:
# Here are your options
#                                 name alpha-3
# 27  bonaire, sint eustatius and saba     BES
# replacing (bonaire, saint eustatius and saba) with (bonaire, sint eustatius and saba)
# ----------------------------------------------------------------------
# You are correcting palestinian territory occupied:
# Here are your options
#                     name alpha-3
# 169                palau     PLW
# 170  palestine, state of     PSE
# replacing (palestinian territory occupied) with (palestine, state of)
# ----------------------------------------------------------------------

# %%
nones = [keys for keys in country_corrections.keys() if country_corrections[keys] == None]
nones
# Out:
# ['united states',
#  'turkey',
#  "cote d'ivoire (ivory coast)",
#  'swaziland',
#  'macedonia',
#  'aland islands',
#  'virgin islands (us)',
#  'reunion',
#  'man (isle of)',
#  'tanzania',
#  'east timor',
#  'vatican city state (holy see)',
#  'cape verde',
#  'korea north',
#  'kosovo']

# %%
for name in nones:
    print(f'You are correcting {name}:')
    print('Here are your options')
    options = country_codes[country_codes['name'].str.startswith(name[:3])]
    print(options)
    correct_index = input('Which index is correct?')
    if correct_index == 'na':
        print('no equivalent value')
        continue
    print(f'replacing ({name}) with ({options['name'].loc[int(correct_index)]})')
    country_corrections[name] = options['name'].loc[int(correct_index)]
    print('-'*70)
# Out:
# You are correcting united states:
# Here are your options
#                                                   name alpha-3
# 233                               united arab emirates     ARE
# 234  united kingdom of great britain and northern i...     GBR
# 235                           united states of america     USA
# 236               united states minor outlying islands     UMI
# replacing (united states) with (united states of america)
# ----------------------------------------------------------------------
# You are correcting turkey:
# Here are your options
#                          name alpha-3
# 228              turkmenistan     TKM
# 229  turks and caicos islands     TCA
# no equivalent value
# You are correcting cote d'ivoire (ivory coast):
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting swaziland:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting macedonia:
# Here are your options
#       name alpha-3
# 131  macao     MAC
# no equivalent value
# You are correcting aland islands:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting virgin islands (us):
# Here are your options
#                          name alpha-3
# 242  virgin islands (british)     VGB
# 243     virgin islands (u.s.)     VIR
# replacing (virgin islands (us)) with (virgin islands (u.s.))
# ----------------------------------------------------------------------
# You are correcting reunion:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting man (isle of):
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting tanzania:
# Here are your options
#                              name alpha-3
# 219  tanzania, united republic of     TZA
# replacing (tanzania) with (tanzania, united republic of)
# ----------------------------------------------------------------------
# You are correcting east timor:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting vatican city state (holy see):
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting cape verde:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value
# You are correcting korea north:
# Here are your options
#                                        name alpha-3
# 118  korea, democratic people's republic of     PRK
# 119                      korea, republic of     KOR
# replacing (korea north) with (korea, democratic people's republic of)
# ----------------------------------------------------------------------
# You are correcting kosovo:
# Here are your options
# Empty DataFrame
# Columns: [name, alpha-3]
# Index: []
# no equivalent value

# %%
nones = [keys for keys in country_corrections.keys() if country_corrections[keys] == None]
nones
# Out:
# ['turkey',
#  "cote d'ivoire (ivory coast)",
#  'swaziland',
#  'macedonia',
#  'aland islands',
#  'reunion',
#  'man (isle of)',
#  'east timor',
#  'vatican city state (holy see)',
#  'cape verde',
#  'kosovo']

# %%
country_codes[country_codes['name'].str.startswith('tim')]
# Out:
#             name alpha-3
# 221  timor-leste     TLS

# %%
country_corrections['east timor'] = 'timor-leste'
country_corrections['turkey'] = 'türkiye'

# %%
imports_data['corrected_name'] = imports_data['Origin_Country'].replace(country_corrections)
imports_data.tail()
# Out:
#               TEU  Month Origin_Country  HS_Codes corrected_name
# 4158449  1.000000      3          china    960390          china
# 4158450  0.729055      3         turkey    610433        türkiye
# 4158451  0.041950      3        germany    510910        germany
# 4158452  2.000000      3         turkey    680291        türkiye
# 4158453  2.000000      3          china    950300          china

# %%
merged_df = pd.merge(imports_data, country_codes, left_on = 'corrected_name', right_on = 'name', how = 'left')
merged_df.head()
# Out:
#         TEU  Month Origin_Country  HS_Codes corrected_name     name alpha-3
# 0  0.849421      1         poland    990500         poland   poland     POL
# 1  1.000000      1          italy    330590          italy    italy     ITA
# 2  2.000000      1        belgium    730890        belgium  belgium     BEL
# 3  0.035356      1        germany    580620        germany  germany     DEU
# 4  4.000000      1        denmark    392030        denmark  denmark     DNK

# %%
merged_df[merged_df['name'].isna()]['Origin_Country'].unique()
# Out:
# array(["cote d'ivoire (ivory coast)", 'swaziland', 'macedonia',
#        'aland islands', 'reunion', 'man (isle of)',
#        'vatican city state (holy see)', 'cape verde', 'kosovo'],
#       dtype=object)

# %%
merged_df[merged_df['name'].isna()]['Origin_Country'].value_counts()
# Out:
# Origin_Country
# cote d'ivoire (ivory coast)      1800
# reunion                          1137
# aland islands                     233
# macedonia                         168
# swaziland                         112
# vatican city state (holy see)      17
# man (isle of)                      13
# cape verde                          5
# kosovo                              1
# Name: count, dtype: int64

# %%
merged_df.drop(columns=['corrected_name'], inplace=True)

# %% [markdown]
# ## merge wgi_data

# %%
merged_df.head()
# Out:
#         TEU  Month Origin_Country  HS_Codes     name alpha-3
# 0  0.849421      1         poland    990500   poland     POL
# 1  1.000000      1          italy    330590    italy     ITA
# 2  2.000000      1        belgium    730890  belgium     BEL
# 3  0.035356      1        germany    580620  germany     DEU
# 4  4.000000      1        denmark    392030  denmark     DNK

# %%
wgi_data.head()
# Out:
#       code     countryname  estimate
# 30816  AFG     Afghanistan -1.154932
# 30817  ALB         Albania -0.332219
# 30818  DZA         Algeria -0.589308
# 30819  ASM  American Samoa  1.251356
# 30820  ADO         Andorra  1.251356

# %%
merged_df2 = pd.merge(merged_df, wgi_data, left_on = 'alpha-3', right_on = 'code', how = 'left')
merged_df2.head()
# Out:
#         TEU  Month Origin_Country  HS_Codes    name alpha-3 code countryname  \
# 0  0.849421      1         poland    990500  poland     POL  POL      Poland
# 1  0.849421      1         poland    990500  poland     POL  POL      Poland
# 2  0.849421      1         poland    990500  poland     POL  POL      Poland
# 3  0.849421      1         poland    990500  poland     POL  POL      Poland
# 4  0.849421      1         poland    990500  poland     POL  POL      Poland
#
#    estimate
# 0    0.5654
# 1  0.421438
# 2  0.559585
# 3  0.458741
# 4  0.780194

# %%
merged_df2[merged_df2['code'].isna()][['name','alpha-3','code']]
# Out:
#              name alpha-3 code
# 672       romania     ROU  NaN
# 673       romania     ROU  NaN
# 674       romania     ROU  NaN
# 675       romania     ROU  NaN
# 676       romania     ROU  NaN
# ...           ...     ...  ...
# 24846444  romania     ROU  NaN
# 24847261  andorra     AND  NaN
# 24847262  andorra     AND  NaN
# 24847263  andorra     AND  NaN
# 24847264  andorra     AND  NaN
#
# [20297 rows x 3 columns]

# %%
wgi_data[wgi_data['countryname'].str.startswith('Ro')]
# Out:
#       code countryname  estimate
# 30974  ROM     Romania  0.040495
# 31188  ROM     Romania -0.092666
# 31402  ROM     Romania  0.373644
# 31616  ROM     Romania  0.437426
# 31830  ROM     Romania  0.318901
# 32044  ROM     Romania   0.50318

# %%
merged_df.to_csv('../data/processed_data/merged_df.csv')
merged_df2.to_csv('../data/processed_data/merged_df2.csv')
